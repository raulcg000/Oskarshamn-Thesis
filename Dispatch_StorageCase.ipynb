# %%
from pulp import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Input data
heat_demand = pd.read_csv('heat_demand_48h.csv', index_col=False)
el_demand = pd.read_csv('electric_demand.csv', index_col=False)
el_prices = pd.read_csv('electric_prices.csv', index_col=False)
eon_elprice = pd.read_csv('eon_elprice.csv', index_col=False)

# %%
heat_demand

# %%
# Input data
#heat_demand = pd.read_csv('heat_demand.csv', index_col=False)
#el_demand = pd.read_csv('electric_demand.csv', index_col=False)
#el_prices = pd.read_csv('electric_prices.csv', index_col=False)
#eon_elprice = pd.read_csv('eon_elprice.csv', index_col=False)

# Resource data
resources_heat = {
   
    'CHP_heat': {
        'min': 6,
        'max': 18.5,
        'efficiency': 1,
        'cost': 195.4       
         },
    'WC1_boiler': {
        'min': 4,
        'max': 9,
        'efficiency': 0.85,
        'cost': 195.4
    },
    'bio_oil_boiler_1': {
        'min': 0,
        'max': 6,
        'efficiency': 0.76,
        'cost': 1548.6
    },
    'bio_oil_boiler_2': {
        'min': 0,
        'max': 6,
        'efficiency': 0.76,
        'cost': 1548.6
    },
    'wood_pellets_boiler_1': {
        'min': 0.5,
        'max': 3.25,
        'efficiency': 0.87,
        'cost': 455.2 
    },
    'wood_pellets_boiler_2': {
        'min': 0.5,
        'max': 3.25,
        'efficiency': 0.87,
        'cost': 455.2 
    },
    'bio_oil_boiler_3': {
        'min': 0,
        'max': 10,
        'efficiency': 0.875,
        'cost': 1548.6
    }
}

resources_el = {
  'CHP_el': {
        'min': 0.8,
        'max': 3.9,
        'efficiency': 0.4,
        'cost': 248.5
    }}

Network_losses=0.091 # 9.1%

Storage_capacity = 100 #MWh PRELIMINARY VALUE

Storage_losses = 0.015 #1.5%/hour PRELIMINARY VALUE

Storage_maxrate = 30 #MW PRELIMINARY VALUE


# Initialize the optimization problem....................................................................................................

prob = LpProblem("District Heating Plant Dispatch Optimization", LpMinimize)


# Initialize the decision variables....................................................................................................

variables = LpVariable.dicts("Fuel", ((r, t) for r in resources_heat for t in heat_demand.index), lowBound=0, cat='Continuous')
b_heat = LpVariable("b_heat", cat="Binary")
storage_in=LpVariable.dict("Storage in", [t for t in heat_demand.index], lowBound=0, upBound=Storage_maxrate, cat='Continuous') # MWh
storage_out=LpVariable.dict("Storage out", [t for t in heat_demand.index], lowBound=0, upBound=Storage_maxrate, cat='Continuous') # MWh


      
# Objective function.............................................................................................

prob += lpSum([variables[(r, t)] * resources_heat[r]['cost'] for r in resources_heat for t in heat_demand.index])

Storage_state=0

# Constraints....................................................................................................
for t in heat_demand.index:
    #Charge/Discharge rate
    
    prob += storage_in[t]<= Storage_maxrate
    prob += storage_out[t]<= Storage_maxrate
    prob += storage_in[t]>= 0
    prob += storage_out[t]>= 0
    
    # Heat demand constraint
    heat_production = lpSum([variables[(r, t)]  for r in resources_heat]) 
                     
    
    prob += heat_production >= (1+Network_losses)*heat_demand.loc[t]  + storage_in[t] -  storage_out[t] 

    #Storage constrains
    
    Storage_state =(Storage_state + storage_in[t] - storage_out[t])*(1-Storage_losses)
                         
    prob += Storage_state <= Storage_capacity
    prob += Storage_state >= 0

    
    # Resource capacity constraints
    for r in resources_heat:
            prob += variables[(r, t)] <= resources_heat[r]['max']

    # Resource minimum load constraints
    prob += variables[(r, t)] >= resources_heat[r]['min']*b_heat
    
    

    
     
    
    # Solve the optimization problem
prob.solve()


# Print the status of the solution
print("Status:", LpStatus[prob.status])

# Print the optimal value of the objective function
#print("Optimal Value: ", value(prob.objective))

# Print the values of the decision variables
for v in prob.variables():
    print(v.name, "=", v.varValue)


# Define decision variables
chp_heat = {}
WC1 = {}
bio_oil_1 = {}
bio_oil_2 = {}
wood_pellets_1 = {}
wood_pellets_2 = {}

# Populate the decision variables with the optimal values
for i in heat_demand.index:
    chp_heat[i] = variables[('CHP_heat', i)]
    WC1[i] = variables[('WC1_boiler', i)]
    bio_oil_1[i] = variables[('bio_oil_boiler_1', i)]
    bio_oil_2[i] = variables[('bio_oil_boiler_2', i)]
    wood_pellets_1[i] = variables[('wood_pellets_boiler_1', i)]
    wood_pellets_2[i] = variables[('wood_pellets_boiler_2', i)]

# Populate the results DataFrame with the optimal values of the decision variables
results = pd.DataFrame(index=heat_demand.index, columns=['CHP_heat','WC1_boiler', 'Bio_oil_1', 'Bio_oil_2', 'wood_pellets_boiler_1', 'wood_pellets_boiler_2'])

for i in heat_demand.index:
    results.loc[i, 'CHP_heat'] = chp_heat[i].varValue
    results.loc[i, 'WC1_boiler'] = WC1[i].varValue
    results.loc[i, 'Bio_oil_1'] = bio_oil_1[i].varValue
    results.loc[i, 'Bio_oil_2'] = bio_oil_2[i].varValue
    results.loc[i, 'Bio_oil_3'] = bio_oil_2[i].varValue
    results.loc[i, 'wood_pellets_boiler_1'] = wood_pellets_1[i].varValue
    results.loc[i, 'wood_pellets_boiler_2'] = wood_pellets_2[i].varValue

# Print the results
#print(results)

results.to_excel("results.xlsx", index=False)
# Out:
# /Users/raul/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/raul/opt/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/9k/hgnlw0z55v183zl9_r5xj9w40000gn/T/68a037d842ec48d99ac3395e508bae90-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/9k/hgnlw0z55v183zl9_r5xj9w40000gn/T/68a037d842ec48d99ac3395e508bae90-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 725 COLUMNS
# At line 6774 RHS
# At line 7495 BOUNDS
# At line 7592 ENDATA
# Problem MODEL has 720 rows, 432 columns and 5712 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 141 (-579) rows, 323 (-109) columns and 5015 (-697) elements
# Perturbing problem by 0.001% of 1548.6 - largest nonzero change 0.00017053445 ( 1.8383649e-05%) - largest zero change 0.00017027658
# 0  Obj 0 Primal inf 1090.8114 (48)
# 47  Obj 178924.21 Primal inf 860.96282 (56)
# 98  Obj 222640.06 Primal inf 28.992616 (12)
# 109  Obj 222682.43
# Optimal - objective value 222682.37
# After Postsolve, objective 222682.37, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 222682.3656 - 109 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Status: Optimal
# Fuel_('CHP_heat',_0) = 18.5
# Fuel_('CHP_heat',_1) = 18.5
# Fuel_('CHP_heat',_10) = 18.5
# Fuel_('CHP_heat',_11) = 18.5
# Fuel_('CHP_heat',_12) = 18.5
# Fuel_('CHP_heat',_13) = 18.5
# Fuel_('CHP_heat',_14) = 18.5
# Fuel_('CHP_heat',_15) = 18.5
# Fuel_('CHP_heat',_16) = 11.917279
# Fuel_('CHP_heat',_17) = 0.0
# Fuel_('CHP_heat',_18) = 2.182
# Fuel_('CHP_heat',_19) = 5.5150837
# Fuel_('CHP_heat',_2) = 18.5
# Fuel_('CHP_heat',_20) = 18.5
# Fuel_('CHP_heat',_21) = 18.5
# Fuel_('CHP_heat',_22) = 18.5
# Fuel_('CHP_heat',_23) = 18.5
# Fuel_('CHP_heat',_24) = 18.5
# Fuel_('CHP_heat',_25) = 18.5
# Fuel_('CHP_heat',_26) = 18.5
# Fuel_('CHP_heat',_27) = 18.5
# Fuel_('CHP_heat',_28) = 18.5
# Fuel_('CHP_heat',_29) = 18.5
# Fuel_('CHP_heat',_3) = 18.5
# Fuel_('CHP_heat',_30) = 18.5
# Fuel_('CHP_heat',_31) = 18.5
# Fuel_('CHP_heat',_32) = 18.5
# Fuel_('CHP_heat',_33) = 18.5
# Fuel_('CHP_heat',_34) = 16.095215
# Fuel_('CHP_heat',_35) = 14.913018
# Fuel_('CHP_heat',_36) = 18.5
# Fuel_('CHP_heat',_37) = 18.5
# Fuel_('CHP_heat',_38) = 18.5
# Fuel_('CHP_heat',_39) = 12.61595
# Fuel_('CHP_heat',_4) = 18.5
# Fuel_('CHP_heat',_40) = 18.5
# Fuel_('CHP_heat',_41) = 0.0
# Fuel_('CHP_heat',_42) = 0.0
# Fuel_('CHP_heat',_43) = 0.0
# Fuel_('CHP_heat',_44) = 18.5
# Fuel_('CHP_heat',_45) = 18.5
# Fuel_('CHP_heat',_46) = 18.5
# Fuel_('CHP_heat',_47) = 18.5
# Fuel_('CHP_heat',_5) = 18.5
# Fuel_('CHP_heat',_6) = 18.5
# Fuel_('CHP_heat',_7) = 18.5
# Fuel_('CHP_heat',_8) = 18.5
# Fuel_('CHP_heat',_9) = 18.5
# Fuel_('WC1_boiler',_0) = 9.0
# Fuel_('WC1_boiler',_1) = 9.0
# Fuel_('WC1_boiler',_10) = 6.5952147
# Fuel_('WC1_boiler',_11) = 5.413018
# Fuel_('WC1_boiler',_12) = 5.7309409
# Fuel_('WC1_boiler',_13) = 4.2434279
# Fuel_('WC1_boiler',_14) = 2.8865839
# Fuel_('WC1_boiler',_15) = 3.1159503
# Fuel_('WC1_boiler',_16) = 9.0
# Fuel_('WC1_boiler',_17) = 1.091
# Fuel_('WC1_boiler',_18) = 0.0
# Fuel_('WC1_boiler',_19) = 0.0
# Fuel_('WC1_boiler',_2) = 9.0
# Fuel_('WC1_boiler',_20) = 9.0
# Fuel_('WC1_boiler',_21) = 9.0
# Fuel_('WC1_boiler',_22) = 9.0
# Fuel_('WC1_boiler',_23) = 9.0
# Fuel_('WC1_boiler',_24) = 9.0
# Fuel_('WC1_boiler',_25) = 9.0
# Fuel_('WC1_boiler',_26) = 9.0
# Fuel_('WC1_boiler',_27) = 9.0
# Fuel_('WC1_boiler',_28) = 9.0
# Fuel_('WC1_boiler',_29) = 9.0
# Fuel_('WC1_boiler',_3) = 9.0
# Fuel_('WC1_boiler',_30) = 9.0
# Fuel_('WC1_boiler',_31) = 9.0
# Fuel_('WC1_boiler',_32) = 9.0
# Fuel_('WC1_boiler',_33) = 8.2064854
# Fuel_('WC1_boiler',_34) = 9.0
# Fuel_('WC1_boiler',_35) = 9.0
# Fuel_('WC1_boiler',_36) = 5.7309409
# Fuel_('WC1_boiler',_37) = 4.2434279
# Fuel_('WC1_boiler',_38) = 2.8865839
# Fuel_('WC1_boiler',_39) = 9.0
# Fuel_('WC1_boiler',_4) = 9.0
# Fuel_('WC1_boiler',_40) = 2.4172793
# Fuel_('WC1_boiler',_41) = 1.091
# Fuel_('WC1_boiler',_42) = 2.182
# Fuel_('WC1_boiler',_43) = 3.273
# Fuel_('WC1_boiler',_44) = 1.1545341
# Fuel_('WC1_boiler',_45) = 1.8185112
# Fuel_('WC1_boiler',_46) = 1.8328306
# Fuel_('WC1_boiler',_47) = 0.76458343
# Fuel_('WC1_boiler',_5) = 9.0
# Fuel_('WC1_boiler',_6) = 9.0
# Fuel_('WC1_boiler',_7) = 9.0
# Fuel_('WC1_boiler',_8) = 9.0
# Fuel_('WC1_boiler',_9) = 8.2064854
# Fuel_('bio_oil_boiler_1',_0) = 0.0
# Fuel_('bio_oil_boiler_1',_1) = 0.0
# Fuel_('bio_oil_boiler_1',_10) = 0.0
# Fuel_('bio_oil_boiler_1',_11) = 0.0
# Fuel_('bio_oil_boiler_1',_12) = 0.0
# Fuel_('bio_oil_boiler_1',_13) = 0.0
# Fuel_('bio_oil_boiler_1',_14) = 0.0
# Fuel_('bio_oil_boiler_1',_15) = 0.0
# Fuel_('bio_oil_boiler_1',_16) = 0.0
# Fuel_('bio_oil_boiler_1',_17) = 0.0
# Fuel_('bio_oil_boiler_1',_18) = 0.0
# Fuel_('bio_oil_boiler_1',_19) = 0.0
# Fuel_('bio_oil_boiler_1',_2) = 0.0
# Fuel_('bio_oil_boiler_1',_20) = 0.0
# Fuel_('bio_oil_boiler_1',_21) = 0.0
# Fuel_('bio_oil_boiler_1',_22) = 0.0
# Fuel_('bio_oil_boiler_1',_23) = 0.0
# Fuel_('bio_oil_boiler_1',_24) = 0.0
# Fuel_('bio_oil_boiler_1',_25) = 0.0
# Fuel_('bio_oil_boiler_1',_26) = 0.0
# Fuel_('bio_oil_boiler_1',_27) = 0.0
# Fuel_('bio_oil_boiler_1',_28) = 0.0
# Fuel_('bio_oil_boiler_1',_29) = 0.0
# Fuel_('bio_oil_boiler_1',_3) = 0.0
# Fuel_('bio_oil_boiler_1',_30) = 0.0
# Fuel_('bio_oil_boiler_1',_31) = 0.0
# Fuel_('bio_oil_boiler_1',_32) = 0.0
# Fuel_('bio_oil_boiler_1',_33) = 0.0
# Fuel_('bio_oil_boiler_1',_34) = 0.0
# Fuel_('bio_oil_boiler_1',_35) = 0.0
# Fuel_('bio_oil_boiler_1',_36) = 0.0
# Fuel_('bio_oil_boiler_1',_37) = 0.0
# Fuel_('bio_oil_boiler_1',_38) = 0.0
# Fuel_('bio_oil_boiler_1',_39) = 0.0
# Fuel_('bio_oil_boiler_1',_4) = 0.0
# Fuel_('bio_oil_boiler_1',_40) = 0.0
# Fuel_('bio_oil_boiler_1',_41) = 0.0
# Fuel_('bio_oil_boiler_1',_42) = 0.0
# Fuel_('bio_oil_boiler_1',_43) = 0.0
# Fuel_('bio_oil_boiler_1',_44) = 0.0
# Fuel_('bio_oil_boiler_1',_45) = 0.0
# Fuel_('bio_oil_boiler_1',_46) = 0.0
# Fuel_('bio_oil_boiler_1',_47) = 0.0
# Fuel_('bio_oil_boiler_1',_5) = 0.0
# Fuel_('bio_oil_boiler_1',_6) = 0.0
# Fuel_('bio_oil_boiler_1',_7) = 0.0
# Fuel_('bio_oil_boiler_1',_8) = 0.0
# Fuel_('bio_oil_boiler_1',_9) = 0.0
# Fuel_('bio_oil_boiler_2',_0) = 0.0
# Fuel_('bio_oil_boiler_2',_1) = 0.0
# Fuel_('bio_oil_boiler_2',_10) = 0.0
# Fuel_('bio_oil_boiler_2',_11) = 0.0
# Fuel_('bio_oil_boiler_2',_12) = 0.0
# Fuel_('bio_oil_boiler_2',_13) = 0.0
# Fuel_('bio_oil_boiler_2',_14) = 0.0
# Fuel_('bio_oil_boiler_2',_15) = 0.0
# Fuel_('bio_oil_boiler_2',_16) = 0.0
# Fuel_('bio_oil_boiler_2',_17) = 0.0
# Fuel_('bio_oil_boiler_2',_18) = 0.0
# Fuel_('bio_oil_boiler_2',_19) = 0.0
# Fuel_('bio_oil_boiler_2',_2) = 0.0
# Fuel_('bio_oil_boiler_2',_20) = 0.0
# Fuel_('bio_oil_boiler_2',_21) = 0.0
# Fuel_('bio_oil_boiler_2',_22) = 0.0
# Fuel_('bio_oil_boiler_2',_23) = 0.0
# Fuel_('bio_oil_boiler_2',_24) = 0.0
# Fuel_('bio_oil_boiler_2',_25) = 0.0
# Fuel_('bio_oil_boiler_2',_26) = 0.0
# Fuel_('bio_oil_boiler_2',_27) = 0.0
# Fuel_('bio_oil_boiler_2',_28) = 0.0
# Fuel_('bio_oil_boiler_2',_29) = 0.0
# Fuel_('bio_oil_boiler_2',_3) = 0.0
# Fuel_('bio_oil_boiler_2',_30) = 0.0
# Fuel_('bio_oil_boiler_2',_31) = 0.0
# Fuel_('bio_oil_boiler_2',_32) = 0.0
# Fuel_('bio_oil_boiler_2',_33) = 0.0
# Fuel_('bio_oil_boiler_2',_34) = 0.0
# Fuel_('bio_oil_boiler_2',_35) = 0.0
# Fuel_('bio_oil_boiler_2',_36) = 0.0
# Fuel_('bio_oil_boiler_2',_37) = 0.0
# Fuel_('bio_oil_boiler_2',_38) = 0.0
# Fuel_('bio_oil_boiler_2',_39) = 0.0
# Fuel_('bio_oil_boiler_2',_4) = 0.0
# Fuel_('bio_oil_boiler_2',_40) = 0.0
# Fuel_('bio_oil_boiler_2',_41) = 0.0
# Fuel_('bio_oil_boiler_2',_42) = 0.0
# Fuel_('bio_oil_boiler_2',_43) = 0.0
# Fuel_('bio_oil_boiler_2',_44) = 0.0
# Fuel_('bio_oil_boiler_2',_45) = 0.0
# Fuel_('bio_oil_boiler_2',_46) = 0.0
# Fuel_('bio_oil_boiler_2',_47) = 0.0
# Fuel_('bio_oil_boiler_2',_5) = 0.0
# Fuel_('bio_oil_boiler_2',_6) = 0.0
# Fuel_('bio_oil_boiler_2',_7) = 0.0
# Fuel_('bio_oil_boiler_2',_8) = 0.0
# Fuel_('bio_oil_boiler_2',_9) = 0.0
# Fuel_('bio_oil_boiler_3',_0) = 0.0
# Fuel_('bio_oil_boiler_3',_1) = 0.0
# Fuel_('bio_oil_boiler_3',_10) = 0.0
# Fuel_('bio_oil_boiler_3',_11) = 0.0
# Fuel_('bio_oil_boiler_3',_12) = 0.0
# Fuel_('bio_oil_boiler_3',_13) = 0.0
# Fuel_('bio_oil_boiler_3',_14) = 0.0
# Fuel_('bio_oil_boiler_3',_15) = 0.0
# Fuel_('bio_oil_boiler_3',_16) = 0.0
# Fuel_('bio_oil_boiler_3',_17) = 0.0
# Fuel_('bio_oil_boiler_3',_18) = 0.0
# Fuel_('bio_oil_boiler_3',_19) = 0.0
# Fuel_('bio_oil_boiler_3',_2) = 0.0
# Fuel_('bio_oil_boiler_3',_20) = 0.0
# Fuel_('bio_oil_boiler_3',_21) = 0.0
# Fuel_('bio_oil_boiler_3',_22) = 0.0
# Fuel_('bio_oil_boiler_3',_23) = 0.0
# Fuel_('bio_oil_boiler_3',_24) = 0.0
# Fuel_('bio_oil_boiler_3',_25) = 0.0
# Fuel_('bio_oil_boiler_3',_26) = 0.0
# Fuel_('bio_oil_boiler_3',_27) = 0.0
# Fuel_('bio_oil_boiler_3',_28) = 0.0
# Fuel_('bio_oil_boiler_3',_29) = 0.0
# Fuel_('bio_oil_boiler_3',_3) = 0.0
# Fuel_('bio_oil_boiler_3',_30) = 0.0
# Fuel_('bio_oil_boiler_3',_31) = 0.0
# Fuel_('bio_oil_boiler_3',_32) = 0.0
# Fuel_('bio_oil_boiler_3',_33) = 0.0
# Fuel_('bio_oil_boiler_3',_34) = 0.0
# Fuel_('bio_oil_boiler_3',_35) = 0.0
# Fuel_('bio_oil_boiler_3',_36) = 0.0
# Fuel_('bio_oil_boiler_3',_37) = 0.0
# Fuel_('bio_oil_boiler_3',_38) = 0.0
# Fuel_('bio_oil_boiler_3',_39) = 0.0
# Fuel_('bio_oil_boiler_3',_4) = 0.0
# Fuel_('bio_oil_boiler_3',_40) = 0.0
# Fuel_('bio_oil_boiler_3',_41) = 0.0
# Fuel_('bio_oil_boiler_3',_42) = 0.0
# Fuel_('bio_oil_boiler_3',_43) = 0.0
# Fuel_('bio_oil_boiler_3',_44) = 0.0
# Fuel_('bio_oil_boiler_3',_45) = 0.0
# Fuel_('bio_oil_boiler_3',_46) = 0.0
# Fuel_('bio_oil_boiler_3',_47) = 0.0
# Fuel_('bio_oil_boiler_3',_5) = 0.0
# Fuel_('bio_oil_boiler_3',_6) = 0.0
# Fuel_('bio_oil_boiler_3',_7) = 0.0
# Fuel_('bio_oil_boiler_3',_8) = 0.0
# Fuel_('bio_oil_boiler_3',_9) = 0.0
# Fuel_('wood_pellets_boiler_1',_0) = 0.0
# Fuel_('wood_pellets_boiler_1',_1) = 0.0
# Fuel_('wood_pellets_boiler_1',_10) = 0.0
# Fuel_('wood_pellets_boiler_1',_11) = 0.0
# Fuel_('wood_pellets_boiler_1',_12) = 0.0
# Fuel_('wood_pellets_boiler_1',_13) = 0.0
# Fuel_('wood_pellets_boiler_1',_14) = 0.0
# Fuel_('wood_pellets_boiler_1',_15) = 0.0
# Fuel_('wood_pellets_boiler_1',_16) = 0.0
# Fuel_('wood_pellets_boiler_1',_17) = 0.0
# Fuel_('wood_pellets_boiler_1',_18) = 0.0
# Fuel_('wood_pellets_boiler_1',_19) = 0.0
# Fuel_('wood_pellets_boiler_1',_2) = 0.0
# Fuel_('wood_pellets_boiler_1',_20) = 0.0
# Fuel_('wood_pellets_boiler_1',_21) = 0.0
# Fuel_('wood_pellets_boiler_1',_22) = 0.0
# Fuel_('wood_pellets_boiler_1',_23) = 0.0
# Fuel_('wood_pellets_boiler_1',_24) = 0.0
# Fuel_('wood_pellets_boiler_1',_25) = 0.0
# Fuel_('wood_pellets_boiler_1',_26) = 0.0
# Fuel_('wood_pellets_boiler_1',_27) = 0.0
# Fuel_('wood_pellets_boiler_1',_28) = 0.0
# Fuel_('wood_pellets_boiler_1',_29) = 0.0
# Fuel_('wood_pellets_boiler_1',_3) = 0.0
# Fuel_('wood_pellets_boiler_1',_30) = 0.0
# Fuel_('wood_pellets_boiler_1',_31) = 0.0
# Fuel_('wood_pellets_boiler_1',_32) = 0.0
# Fuel_('wood_pellets_boiler_1',_33) = 0.0
# Fuel_('wood_pellets_boiler_1',_34) = 0.0
# Fuel_('wood_pellets_boiler_1',_35) = 0.0
# Fuel_('wood_pellets_boiler_1',_36) = 0.0
# Fuel_('wood_pellets_boiler_1',_37) = 0.0
# Fuel_('wood_pellets_boiler_1',_38) = 0.0
# Fuel_('wood_pellets_boiler_1',_39) = 0.0
# Fuel_('wood_pellets_boiler_1',_4) = 2.5462646
# Fuel_('wood_pellets_boiler_1',_40) = 0.0
# Fuel_('wood_pellets_boiler_1',_41) = 0.0
# Fuel_('wood_pellets_boiler_1',_42) = 0.0
# Fuel_('wood_pellets_boiler_1',_43) = 0.0
# Fuel_('wood_pellets_boiler_1',_44) = 0.0
# Fuel_('wood_pellets_boiler_1',_45) = 0.0
# Fuel_('wood_pellets_boiler_1',_46) = 0.0
# Fuel_('wood_pellets_boiler_1',_47) = 0.0
# Fuel_('wood_pellets_boiler_1',_5) = 3.25
# Fuel_('wood_pellets_boiler_1',_6) = 3.25
# Fuel_('wood_pellets_boiler_1',_7) = 3.25
# Fuel_('wood_pellets_boiler_1',_8) = 3.25
# Fuel_('wood_pellets_boiler_1',_9) = 0.0
# Fuel_('wood_pellets_boiler_2',_0) = 0.0
# Fuel_('wood_pellets_boiler_2',_1) = 0.0
# Fuel_('wood_pellets_boiler_2',_10) = 0.0
# Fuel_('wood_pellets_boiler_2',_11) = 0.0
# Fuel_('wood_pellets_boiler_2',_12) = 0.0
# Fuel_('wood_pellets_boiler_2',_13) = 0.0
# Fuel_('wood_pellets_boiler_2',_14) = 0.0
# Fuel_('wood_pellets_boiler_2',_15) = 0.0
# Fuel_('wood_pellets_boiler_2',_16) = 0.0
# Fuel_('wood_pellets_boiler_2',_17) = 0.0
# Fuel_('wood_pellets_boiler_2',_18) = 0.0
# Fuel_('wood_pellets_boiler_2',_19) = 0.0
# Fuel_('wood_pellets_boiler_2',_2) = 0.0
# Fuel_('wood_pellets_boiler_2',_20) = 0.0
# Fuel_('wood_pellets_boiler_2',_21) = 0.0
# Fuel_('wood_pellets_boiler_2',_22) = 0.0
# Fuel_('wood_pellets_boiler_2',_23) = 0.0
# Fuel_('wood_pellets_boiler_2',_24) = 0.0
# Fuel_('wood_pellets_boiler_2',_25) = 0.0
# Fuel_('wood_pellets_boiler_2',_26) = 0.0
# Fuel_('wood_pellets_boiler_2',_27) = 0.0
# Fuel_('wood_pellets_boiler_2',_28) = 0.0
# Fuel_('wood_pellets_boiler_2',_29) = 0.0
# Fuel_('wood_pellets_boiler_2',_3) = 0.0
# Fuel_('wood_pellets_boiler_2',_30) = 0.0
# Fuel_('wood_pellets_boiler_2',_31) = 0.0
# Fuel_('wood_pellets_boiler_2',_32) = 0.0
# Fuel_('wood_pellets_boiler_2',_33) = 0.0
# Fuel_('wood_pellets_boiler_2',_34) = 0.0
# Fuel_('wood_pellets_boiler_2',_35) = 0.0
# Fuel_('wood_pellets_boiler_2',_36) = 0.0
# Fuel_('wood_pellets_boiler_2',_37) = 0.0
# Fuel_('wood_pellets_boiler_2',_38) = 0.0
# Fuel_('wood_pellets_boiler_2',_39) = 0.0
# Fuel_('wood_pellets_boiler_2',_4) = 0.0
# Fuel_('wood_pellets_boiler_2',_40) = 0.0
# Fuel_('wood_pellets_boiler_2',_41) = 0.0
# Fuel_('wood_pellets_boiler_2',_42) = 0.0
# Fuel_('wood_pellets_boiler_2',_43) = 0.0
# Fuel_('wood_pellets_boiler_2',_44) = 0.0
# Fuel_('wood_pellets_boiler_2',_45) = 0.0
# Fuel_('wood_pellets_boiler_2',_46) = 0.0
# Fuel_('wood_pellets_boiler_2',_47) = 0.0
# Fuel_('wood_pellets_boiler_2',_5) = 3.25
# Fuel_('wood_pellets_boiler_2',_6) = 3.25
# Fuel_('wood_pellets_boiler_2',_7) = 3.25
# Fuel_('wood_pellets_boiler_2',_8) = 3.25
# Fuel_('wood_pellets_boiler_2',_9) = 0.0
# Storage_in_0 = 8.8627361
# Storage_in_1 = 8.1248655
# Storage_in_10 = 0.0
# Storage_in_11 = 0.0
# Storage_in_12 = 0.0
# Storage_in_13 = 0.0
# Storage_in_14 = 0.0
# Storage_in_15 = 0.0
# Storage_in_16 = -4.1271431e-13
# Storage_in_17 = 0.0
# Storage_in_18 = 0.0
# Storage_in_19 = 2.2420837
# Storage_in_2 = 7.7706288
# Storage_in_20 = 7.8454659
# Storage_in_21 = 7.1814887
# Storage_in_22 = 7.1671694
# Storage_in_23 = 8.2354166
# Storage_in_24 = 8.8627361
# Storage_in_25 = 8.1248655
# Storage_in_26 = 7.7706288
# Storage_in_27 = 7.3466716
# Storage_in_28 = 5.3035177
# Storage_in_29 = 2.1962133
# Storage_in_3 = 7.3466716
# Storage_in_30 = 0.0
# Storage_in_31 = 0.0
# Storage_in_32 = 0.0
# Storage_in_33 = 0.0
# Storage_in_34 = -6.9319883e-13
# Storage_in_35 = 0.0
# Storage_in_36 = 3.4792835e-13
# Storage_in_37 = 0.0
# Storage_in_38 = 1.9957824e-12
# Storage_in_39 = 0.0
# Storage_in_4 = 7.8497823
# Storage_in_40 = 0.0
# Storage_in_41 = 0.0
# Storage_in_42 = 0.0
# Storage_in_43 = 0.0
# Storage_in_44 = 0.0
# Storage_in_45 = 0.0
# Storage_in_46 = 2.5395119e-12
# Storage_in_47 = 0.0
# Storage_in_5 = 8.6962133
# Storage_in_6 = 0.0
# Storage_in_7 = 0.0
# Storage_in_8 = 0.0
# Storage_in_9 = 0.0
# Storage_out_0 = 0.0
# Storage_out_1 = 0.0
# Storage_out_10 = 8.4880103e-13
# Storage_out_11 = 1.121867e-12
# Storage_out_12 = 4.8578919e-13
# Storage_out_13 = -1.1823742e-12
# Storage_out_14 = -2.0313529e-13
# Storage_out_15 = 7.2001072e-13
# Storage_out_16 = 0.0
# Storage_out_17 = -1.4527757e-12
# Storage_out_18 = -1.7769253e-12
# Storage_out_19 = 0.0
# Storage_out_2 = 0.0
# Storage_out_20 = 0.0
# Storage_out_21 = 0.0
# Storage_out_22 = 0.0
# Storage_out_23 = 0.0
# Storage_out_24 = 0.0
# Storage_out_25 = 0.0
# Storage_out_26 = 0.0
# Storage_out_27 = 0.0
# Storage_out_28 = 0.0
# Storage_out_29 = 0.0
# Storage_out_3 = 0.0
# Storage_out_30 = 16.14
# Storage_out_31 = 21.595
# Storage_out_32 = 27.05
# Storage_out_33 = 6.9411143e-13
# Storage_out_34 = 0.0
# Storage_out_35 = 2.3159286e-12
# Storage_out_36 = 0.0
# Storage_out_37 = -1.8760893e-12
# Storage_out_38 = 0.0
# Storage_out_39 = 7.2955197e-13
# Storage_out_4 = 0.0
# Storage_out_40 = 7.1200268e-13
# Storage_out_41 = -2.2478452e-12
# Storage_out_42 = -2.081898e-12
# Storage_out_43 = 2.0745239e-12
# Storage_out_44 = 3.5783709e-13
# Storage_out_45 = 7.8229867e-13
# Storage_out_46 = 0.0
# Storage_out_47 = 2.7757219e-12
# Storage_out_5 = 0.0
# Storage_out_6 = 9.64
# Storage_out_7 = 15.095
# Storage_out_8 = 20.55
# Storage_out_9 = -4.3431925e-13

# %%
results

# %%
heat_demand*(1+Network_losses)
